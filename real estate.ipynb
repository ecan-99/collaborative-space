# %%
import pandas as pd

df_18 = pd.read_csv('2018.csv', encoding='cp949')
df_18.head()

# # 20억 이상 매물 필터링
# cond = df_18['물건금액(만원)'] >= 200000
# high_price = df_18[cond]
# high_price.sort_values(by = '물건금액(만원)')

# high_price.to_csv('high_price_2018.csv', index= False)

df_18.info()
df_18.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166717 entries, 0 to 166716
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   접수연도              166717 non-null  int64
#  1   자치구코드             166717 non-null  int64
#  2   자치구명              166717 non-null  object
#  3   법정동코드             166717 non-null  int64
#  4   법정동명              166717 non-null  object
#  5   지번구분              152354 non-null  float64
#  6   지번구분명             152354 non-null  object
#  7   본번                152351 non-null  float64
#  8   부번                152351 non-null  float64
#  9   건물명               152371 non-null  object
#  10  계약일               166717 non-null  int64
#  11  물건금액(만원)          166717 non-null  int64
#  12  건물면적(㎡)           166717 non-null  float64
#  13  토지면적(㎡)           142887 non-null  float64
#  14  층                 152371 non-null  float64
#  15  권리구분              2737 non-null    object
# ...

# %%
df_19 = pd.read_csv('2019.csv', encoding='cp949')
df_19.head()

# 20억 이상 매물 필터링
cond = df_19['물건금액(만원)'] >= 200000
high_price = df_19[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2019.csv', index= False)
# Out:
# C:\Users\EC\AppData\Local\Temp\ipykernel_26284\334654974.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_19 = pd.read_csv('2019.csv', encoding='cp949')
#      접수연도  자치구코드 자치구명  법정동코드   법정동명  지번구분 지번구분명      본번   부번         건물명  ...  \
# 76   2019  11680  강남구  10600    대치동   1.0    대지   316.0  0.0          은마  ...
# 88   2019  11200  성동구  11500  성수동2가   1.0    대지   843.0  0.0       힐스테이트  ...
# 140  2019  11680  강남구  11500    수서동   1.0    대지   537.0  0.0  강남 더샵 포레스트  ...
# 144  2019  11680  강남구  10300    개포동   1.0    대지   141.0  0.0    개포주공 1단지  ...
# 231  2019  11680  강남구  10300    개포동   1.0    대지  1280.0  0.0    래미안블레스티지  ...
#
#      물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층  권리구분 취소일    건축년도  건물용도 신고구분  \
# 76     200000    76.79      0.0  12.0   NaN NaN  1979.0   아파트  NaN
# 88     200000   143.00      NaN  17.0   NaN NaN  2009.0   아파트  NaN
# 140    237000   114.49      NaN   9.0   NaN NaN  2016.0   아파트  NaN
# ...

# %%
df_20 = pd.read_csv('2020.csv', encoding='cp949')
df_20.head()

# 20억 이상 매물 필터링
cond = df_20['물건금액(만원)'] >= 200000
high_price = df_20[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2020.csv', index= False)
# Out:
# C:\Users\EC\AppData\Local\Temp\ipykernel_26284\2221022375.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_20 = pd.read_csv('2020.csv', encoding='cp949')

# %%
df_21 = pd.read_csv('2021.csv', encoding='cp949')
df_21.head()

# 20억 이상 매물 필터링
cond = df_21['물건금액(만원)'] >= 200000
high_price = df_21[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2021.csv', index= False)
# Out:
# C:\Users\EC\AppData\Local\Temp\ipykernel_26284\649914251.py:1: DtypeWarning: Columns (7,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_21 = pd.read_csv('2021.csv', encoding='cp949')

# %%
df_22 = pd.read_csv('2022.csv', encoding='cp949')
df_22.head()

# 20억 이상 매물 필터링
cond = df_22['물건금액(만원)'] >= 200000
high_price = df_22[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2022.csv', index= False)

# %%
df_23 = pd.read_csv('2023.csv', encoding='cp949')
df_23.head()

# 20억 이상 매물 필터링
cond = df_23['물건금액(만원)'] >= 200000
high_price = df_23[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2023.csv', index= False)

# %%
df_24 = pd.read_csv('2024.csv', encoding='cp949')
df_24.head()

# 20억 이상 매물 필터링
cond = df_24['물건금액(만원)'] >= 200000
high_price = df_24[cond]
high_price.sort_values(by = '물건금액(만원)')

high_price.to_csv('high_price_2024.csv', index= False)
# Out:
# C:\Users\EC\AppData\Local\Temp\ipykernel_26284\2410047311.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_24 = pd.read_csv('2024.csv', encoding='cp949')

# %%
df = pd.read_csv('high_price_2018.csv')
df1 = pd.read_csv('high_price_2019.csv')
df2 = pd.read_csv('high_price_2020.csv')
df3 = pd.read_csv('high_price_2021.csv')
df4 = pd.read_csv('high_price_2022.csv')
df5 = pd.read_csv('high_price_2023.csv')
df6 = pd.read_csv('high_price_2024.csv')

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic' 



# 자치구명에 따른 건물금액 산점도
plt.scatter(x=df['물건금액(만원)'], y=df['자치구명'])  # 실제 데이터 Series 전달
plt.xticks(rotation=45)  # 라벨 회전
plt.xlim(200000,2000000)
plt.show()

df_size = df6.groupby('자치구명').size()

df_size
# Out:
# 자치구명
# 강남구     1802
# 강동구      111
# 강북구        2
# 강서구        9
# 관악구       20
# 광진구      140
# 구로구        3
# 금천구        3
# 노원구        1
# 도봉구        5
# 동대문구      20
# 동작구       78
# 마포구      173
# 서대문구      21
# 서초구     1441
# 성동구      266
# 성북구       29
# 송파구     1121
# 양천구      195
# 영등포구     203
# 용산구      502
# 은평구        9
# 종로구       66
# 중구        26
# 중랑구        8
# dtype: int64

# %%
3235 #18
4067 #19
5740 #20
6254 #21
3004 #22 급격한 금리 인상과 경기 하방 위험 확대의 영향으로 침체
4368 #23 연초 정부의 규제 완화 정책과 금리 인하 기대감으로 주택 수요 up, 연말 고금리 부담과 매수 심리 위축 등으로 다시 약세
6254 #24 

# 면적당 금액, 자치구 코드, 자치구면, 5년 이내 신축,
